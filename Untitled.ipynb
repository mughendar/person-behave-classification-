# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('p1.csv')

# %%
data.head(1)
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
#
#    Number of Apps Installed  Data Usage (MB/day)  Age Gender  \
# 0                        67                 1122   40   Male
#
#    User Behavior Class
# 0                    4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
data.columns=[i.lower() for i in data.columns]

# %%
data
# Out:
#      user id        device model operating system  app usage time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %%
data['user behavior class'].unique()
# Out:
# array([4, 3, 2, 5, 1], dtype=int64)

# %%
data.head()
# Out:
#    user id    device model operating system  app usage time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    screen on time (hours/day)  battery drain (mah/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    number of apps installed  data usage (mb/day)  age  gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Set the plot size
plt.figure(figsize=(10, 6))

# Corrected scatter plot code
sns.scatterplot(x='screen on time (hours/day)', y='user behavior class', data=data)

# Set plot labels and title
plt.title('Screen on Time vs User Behavior Class')
plt.xlabel('Screen on Time (hours/day)')
plt.ylabel('User Behavior Class')

# Show the plot
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user id                     700 non-null    int64
#  1   device model                700 non-null    object
#  2   operating system            700 non-null    object
#  3   app usage time (min/day)    700 non-null    int64
#  4   screen on time (hours/day)  700 non-null    float64
#  5   battery drain (mah/day)     700 non-null    int64
#  6   number of apps installed    700 non-null    int64
#  7   data usage (mb/day)         700 non-null    int64
#  8   age                         700 non-null    int64
#  9   gender                      700 non-null    object
#  10  user behavior class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
data['sex']=le.fit_transform(data['gender'])

# %%
data['sex']
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 695    1
# 696    1
# 697    0
# 698    1
# 699    0
# Name: sex, Length: 700, dtype: int32

# %%
data.drop(columns=['gender'],inplace=True)

# %%
data.corr()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16152\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                              user id  app usage time (min/day)  \
# user id                     1.000000                 -0.024957
# app usage time (min/day)   -0.024957                  1.000000
# screen on time (hours/day) -0.014287                  0.950333
# battery drain (mah/day)    -0.019377                  0.956385
# number of apps installed   -0.023914                  0.955253
# data usage (mb/day)        -0.014527                  0.942308
# age                         0.045188                  0.004382
# user behavior class        -0.016242                  0.970498
# sex                         0.019259                 -0.004551
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   user id                     700 non-null    int64
#  1   device model                700 non-null    object
#  2   operating system            700 non-null    object
#  3   app usage time (min/day)    700 non-null    int64
#  4   screen on time (hours/day)  700 non-null    float64
#  5   battery drain (mah/day)     700 non-null    int64
#  6   number of apps installed    700 non-null    int64
#  7   data usage (mb/day)         700 non-null    int64
#  8   age                         700 non-null    int64
#  9   user behavior class         700 non-null    int64
#  10  sex                         700 non-null    int32
# dtypes: float64(1), int32(1), int64(7), object(2)
# memory usage: 57.6+ KB

# %%
data.drop(columns=['operating system','device model'],inplace=True)

# %%
data.drop(columns=['user id'],inplace=True)

# %%
data
# Out:
#      app usage time (min/day)  screen on time (hours/day)  \
# 0                         393                         6.4
# 1                         268                         4.7
# 2                         154                         4.0
# 3                         239                         4.8
# 4                         187                         4.3
# ..                        ...                         ...
# 695                        92                         3.9
# 696                       316                         6.8
# 697                        99                         3.1
# 698                        62                         1.7
# 699                       212                         5.4
#
#      battery drain (mah/day)  number of apps installed  data usage (mb/day)  \
# 0                       1872                        67                 1122
# 1                       1331                        42                  944
# ...

# %%
y=data['user behavior class']
x=data.drop(columns=['user behavior class'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (560, 7)

# %%
y_train.shape
# Out:
# (560,)

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
p=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac=accuracy_score(p,y_test)

# %%
ac
# Out:
# 1.0

# %%
import pickle

# %%
with open('model.pkl','wb') as file:
    pickle.dump(model,file)
